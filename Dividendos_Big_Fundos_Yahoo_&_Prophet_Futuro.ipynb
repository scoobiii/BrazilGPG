# %% [markdown]
# <a href="https://colab.research.google.com/github/scoobiii/gdpBrazilgoal/blob/main/Dividendos_Big_Fundos_Yahoo_%26_Prophet_Futuro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ativos Ibovespa
#
# Pagamentos de  Dividendos (valor - definido no plano de negócio [meta], RI news e balanço [resultados])
# )
#
# Frêquencia (data - definido no plano de negócio [meta], RI news e balanço[resultados])
#
# Valorização do ativo (data - definido no plano de negócio [meta], RI news e balanço [resultado])
#
# Na ausência destes dados (compliance, governança profissionalismo) Capital
# Ventures migram para NTNs (notas do tesouro nacional) pagando Selic (13.75%) + prêmio de 6%.
#
# Demissão nas StartUps
# Investidores (bunda mole) no sofá.
#
# Isto converte o governo na maior fintech do mercado, mesmo sendo um picareta que empresta no consignado para o poprua (pessoas em situação de rua) a 50% ao ano (bancos públicos) ou 70% ao ano (bancos privados) para remunerar as NTN's, mesmo com libor a 5%, inflação 8% e roi -3% sob a linha do equador.
#
#
# by zeh sobrinho
# dez/2022

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.5 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
pd.set_option('display.max_rows', 150)

# %%
ativo = yf.download(tickers=['BLK','PBR','FIS','GS','UBS','CGDV','KNSL','JPM','VTI'],actions=True, start='2000-01-01', end='2022-11-01')
ativo
# Out:
# [*********************100%***********************]  9 of 9 completed
#              Adj Close                                                \
#                    BLK       CGDV        FIS          GS         JPM
# Date
# 2000-01-03   10.695268        NaN        NaN   66.160912   24.779469
# 2000-01-04   10.212781        NaN        NaN   61.993656   24.235773
# 2000-01-05   10.132363        NaN        NaN   59.090607   24.086161
# 2000-01-06   10.293191        NaN        NaN   61.619041   24.428114
# 2000-01-07   10.212781        NaN        NaN   61.853176   24.876917
# ...                ...        ...        ...         ...         ...
# 2022-10-25  631.585999  22.309999  79.407219  330.234314  122.699997
# 2022-10-26  633.433228  22.350000  81.582352  333.502869  124.110001
# 2022-10-27  644.536682  22.270000  82.515976  334.983154  124.599998
# 2022-10-28  659.205566  22.799999  84.323616  339.592926  126.080002
# ...

# %%
s_ativos = "RRRP3;ALPA4;ABEV3;AMER3;ASAI3;AZUL4;B3SA3;BPAN4;BBSE3;BRML3;BBDC3;BBDC4;BRAP4;BBAS3;BRKM5;BRFS3;BPAC11;CRFB3;CCRO3;CMIG4;CIEL3;COGN3;CPLE6;CSAN3;CPFE3;CMIN3;CVCB3;CYRE3;DXCO3;ECOR3;ELET3;ELET6;EMBR3;ENBR3;ENGI11;ENEV3;EGIE3;EQTL3;EZTC3;FLRY3;GGBR4;GOAU4;GOLL4;NTCO3;SOMA3;HAPV3;HYPE3;IGTI11;IRBR3;ITSA4;ITUB4;JBSS3;JHSF3;KLBN11;RENT3;LWSA3;LREN3;MGLU3;MRFG3;CASH3;BEEF3;MRVE3;MULT3;PCAR3;PETR3;PETR4;PRIO3;PETZ3;POSI3;QUAL3;RADL3;RDOR3;RAIL3;SBSP3;SANB11;CSNA3;SULA11;SUZB3;TAEE11;VIVT3;TIMS3;TOTS3;UGPA3;USIM5;VALE3;VIIA3;VBBR3;WEGE3;YDUQ3"

# %%
ativos = [a+'.SA' for a in s_ativos.split(';')]

# %%
ativos
# Out:
# ['RRRP3.SA',
#  'ALPA4.SA',
#  'ABEV3.SA',
#  'AMER3.SA',
#  'ASAI3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BPAN4.SA',
#  'BBSE3.SA',
#  'BRML3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BRAP4.SA',
#  'BBAS3.SA',
#  'BRKM5.SA',
#  'BRFS3.SA',
#  'BPAC11.SA',
#  'CRFB3.SA',
#  'CCRO3.SA',
#  'CMIG4.SA',
#  'CIEL3.SA',
#  'COGN3.SA',
#  'CPLE6.SA',
#  'CSAN3.SA',
#  'CPFE3.SA',
#  'CMIN3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'DXCO3.SA',
#  'ECOR3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'EMBR3.SA',
#  'ENBR3.SA',
#  'ENGI11.SA',
#  'ENEV3.SA',
#  'EGIE3.SA',
#  'EQTL3.SA',
#  'EZTC3.SA',
#  'FLRY3.SA',
#  'GGBR4.SA',
#  'GOAU4.SA',
#  'GOLL4.SA',
#  'NTCO3.SA',
#  'SOMA3.SA',
#  'HAPV3.SA',
#  'HYPE3.SA',
#  'IGTI11.SA',
#  'IRBR3.SA',
#  'ITSA4.SA',
#  'ITUB4.SA',
#  'JBSS3.SA',
#  'JHSF3.SA',
#  'KLBN11.SA',
#  'RENT3.SA',
#  'LWSA3.SA',
#  'LREN3.SA',
#  'MGLU3.SA',
#  'MRFG3.SA',
#  'CASH3.SA',
#  'BEEF3.SA',
#  'MRVE3.SA',
#  'MULT3.SA',
#  'PCAR3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
# ...

# %%
len(ativos)
# Out:
# 89

# %%
lista_d = []
for a in ativos:
  print('trabalhando no ativo = ',a)
  dados = yf.download(tickers=a,actions=True, period='Max')
  dp = (dados['Close'][-1]-dados['Open'][0])/dados['Open'][0]*100
  d = dados['Dividends']
  freq = d[d != 0].count()
  td = d.sum()
  lista_d.append([a, td, dp, freq])

df = pd.DataFrame(lista_d, columns=['Ativo','SomaDividendos','DeltaP','Freq'])
# Out:
# trabalhando no ativo =  RRRP3.SA
# [*********************100%***********************]  1 of 1 completed
# trabalhando no ativo =  ALPA4.SA
# [*********************100%***********************]  1 of 1 completed
# trabalhando no ativo =  ABEV3.SA
# [*********************100%***********************]  1 of 1 completed
# trabalhando no ativo =  AMER3.SA
# [*********************100%***********************]  1 of 1 completed
# trabalhando no ativo =  ASAI3.SA
# [*********************100%***********************]  1 of 1 completed
# trabalhando no ativo =  AZUL4.SA
# [*********************100%***********************]  1 of 1 completed
# trabalhando no ativo =  B3SA3.SA
# [*********************100%***********************]  1 of 1 completed
# trabalhando no ativo =  BPAN4.SA
# [*********************100%***********************]  1 of 1 completed
# trabalhando no ativo =  BBSE3.SA
# [*********************100%***********************]  1 of 1 completed
# trabalhando no ativo =  BRML3.SA
# ...

# %%
df.sort_values(by='SomaDividendos',ascending=False)
# Out:
#         Ativo  SomaDividendos         DeltaP  Freq
# 22   CPLE6.SA      168.432804     339.999989    38
# 79   VIVT3.SA       46.424057      50.460179    81
# 84   VALE3.SA       40.315284    2435.428510    30
# 65   PETR4.SA       31.405948     320.595729    50
# 78  TAEE11.SA       30.137720     207.499995    44
# 64   PETR3.SA       27.838570     510.829920    37
# 36   EGIE3.SA       26.064574    1097.187525    46
# 14   BRKM5.SA       25.701218     -99.146213    18
# 12   BRAP4.SA       24.746947     759.142848    26
# 13   BBAS3.SA       24.589939    1149.285719   107
# 31   ELET6.SA       23.017849      96.261087    16
# 24   CPFE3.SA       19.955556   12289.985509    24
# 74  SANB11.SA       19.238878      15.574467    53
# 8    BBSE3.SA       18.371601      87.138631    21
# 30   ELET3.SA       16.801094     115.649468    15
# 41   GOAU4.SA       14.237826     -98.412644    76
# 40   GGBR4.SA       13.225479     -93.457381    80
# ...

# %%
df.sort_values(by='DeltaP',ascending=False)
# Out:
#         Ativo  SomaDividendos         DeltaP  Freq
# 70   RADL3.SA        1.443044  256718.676197    65
# 87   WEGE3.SA        2.400090   21899.654613    86
# 24   CPFE3.SA       19.955556   12289.985509    24
# 54   RENT3.SA        5.328986    4680.258739    73
# 2    ABEV3.SA        6.835001    2877.641753    46
# 84   VALE3.SA       40.315284    2435.428510    30
# 27   CYRE3.SA        8.723588    2083.333310    17
# 13   BBAS3.SA       24.589939    1149.285719   107
# 81   TOTS3.SA        2.997425    1118.675248    37
# 36   EGIE3.SA       26.064574    1097.187525    46
# 49   ITSA4.SA        5.160257     826.632718   114
# 18   CCRO3.SA        7.861781     807.789451    30
# 50   ITUB4.SA       11.985335     764.143366   193
# 12   BRAP4.SA       24.746947     759.142848    26
# 73   SBSP3.SA       11.571257     606.956107    21
# 77   SUZB3.SA        4.771315     587.375021    19
# 10   BBDC3.SA        7.671446     511.163877   212
# ...

# %%
df.sort_values(by='Freq',ascending=False)
# Out:
#         Ativo  SomaDividendos         DeltaP  Freq
# 11   BBDC4.SA        9.326690     -39.240946   221
# 10   BBDC3.SA        7.671446     511.163877   212
# 50   ITUB4.SA       11.985335     764.143366   193
# 49   ITSA4.SA        5.160257     826.632718   114
# 13   BBAS3.SA       24.589939    1149.285719   107
# 87   WEGE3.SA        2.400090   21899.654613    86
# 79   VIVT3.SA       46.424057      50.460179    81
# 40   GGBR4.SA       13.225479     -93.457381    80
# 41   GOAU4.SA       14.237826     -98.412644    76
# 54   RENT3.SA        5.328986    4680.258739    73
# 6    B3SA3.SA        4.032472     -63.312501    67
# 56   LREN3.SA        5.187248     -99.840867    67
# 70   RADL3.SA        1.443044  256718.676197    65
# 74  SANB11.SA       19.238878      15.574467    53
# 65   PETR4.SA       31.405948     320.595729    50
# 76  SULA11.SA        8.008579     184.549094    48
# 2    ABEV3.SA        6.835001    2877.641753    46
# ...
