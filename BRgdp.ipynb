# %% [markdown]
# <a href="https://colab.research.google.com/github/scoobiii/BrazilGPG/blob/main/BRgdp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Meta Brazil Lula
#
# #ODS2026
# Brazil Renda per Capita 14 ETH (USD 16.987,46)
#
# #ODS 2030
# Brazil Renda per Capita 42 ETH (USD 50.000,00)
#
# #ODS 2050
# Brazil Renda  per Capita 150 ETH (USD 182070,01)

# %% [markdown]
# Histórico:
# A criação e distribuição renda per capita brasileira evoluiu para USD13.400,00 (2011) e decaiu para USD7500,00 (2022)

# %% [markdown]
# Aprender com os Universitários:
#
# O Pré-sal em, Maricá, RJ, conquistou renda per capita de USD 2000,00 (2011) para US$ 45.000,00 (2019), maior que o Japão USS39.000,00
#
# Qual a vocação e demanda que cada um dos municipios brasileiros possui?
#
# Basta ser melhor que
#
# .Japão,
#
# .Noruega, renda per capita USD 89.000,00 graças ao Présal noruegues, que sustenta o fundo soberano Norges Bank Investment Management (NBIM) com USD 1.4 trilhões, 4 vezes seu PIB nacional, investidps em 9300 companhias em mais de 70 países.
#
# https://www.nbim.no/en/the-fund/Market-Value/
#
#
# . Mônaco, renda per capita USD 173.000,00.

# %% [markdown]
# ##Mão na massa

# %%
# Python
import pandas as pd
from prophet import Prophet

# %% [markdown]
# Buscar dataset gdpBR 1960 a 2021 do git hub editado á mão até aprender a buscar direto no world bank
#
# mundo trabalhando e o Brasil fazendo merda.
#
# ![assassinos economico.png](data:image/png;base64,...)

# %%
# Python
gdpBR = pd.read_csv('https://raw.githubusercontent.com/scoobiii/brazilG50kG/main/brazilG50Gpropducao3.csv')
gdpBR.head()
# Out:
#            ds     y
# 0  1960-12-12  2359
# 1  1961-01-12  2325
# 2  1962-01-12  2513
# 3  1963-12-12  2956
# 4  1964-12-12  2586

# %% [markdown]
# As previsões são feitas em um dataframe com uma coluna ds contendo as datas para as quais uma previsão deve ser feita. Você pode obter um dataframe adequado que se estenda no futuro por um número especificado de dias usando o método auxiliar Prophet.make_future_dataframe. Por padrão, ele também incluirá as datas do histórico, para que possamos ver o ajuste do modelo também.

# %%
# Python
m = Prophet()
m.fit(gdpBR)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpd2enl887/pk_4kgek.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpd2enl887/_pqv8pbw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81012', 'data', 'file=/tmp/tmpd2enl887/pk_4kgek.json', 'init=/tmp/tmpd2enl887/_pqv8pbw.json', 'output', 'file=/tmp/tmpd2enl887/prophet_model_yiwkrtu/prophet_model-20221118103704.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:37:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:37:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# O método de previsão atribuirá a cada linha no futuro um valor previsto que ele chama de yhat. Se passar datas históricas, isso fornecerá um ajuste dentro da amostra. O objeto de previsão aqui é um novo dataframe que inclui uma coluna yhat com a previsão, bem como colunas para componentes e intervalos de incerteza.

# %%
# Python
future = m.make_future_dataframe(periods=43365)
future.tail()
# Out:
#               ds
# 43422 2140-08-31
# 43423 2140-09-01
# 43424 2140-09-02
# 43425 2140-09-03
# 43426 2140-09-04

# %%
# Python
forecast = m.predict(futuro_gdp_BR)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds         yhat   yhat_lower    yhat_upper
# 4072 2032-12-05  7283.195847  4069.894900  10358.959441
# 4073 2032-12-06  7938.176243  4956.580699  11247.470020
# 4074 2032-12-07  8515.431173  5528.931412  11779.716070
# 4075 2032-12-08  9006.044187  6068.679309  12184.309785
# 4076 2032-12-09  9403.988226  6411.579258  12535.752262

# %% [markdown]
# Você pode plotar a previsão chamando o método Prophet.plot e passando seu dataframe de previsão.

# %%
# Python
fig1 = m.plot(forecast)

# %% [markdown]
# Se quiser ver os componentes de previsão, você pode usar o método Prophet.plot_components. Por padrão, você verá a tendência, a sazonalidade anual e a sazonalidade semanal da série temporal. Se você incluir feriados, também os verá aqui.
#
# O que muda este futuro tenebroso?
#
# ##Metas

# %%
# Python
gdpComponetes = m.plot_components(forecast)

# %%
# Python
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6525a9b9-8682-4a59-9743-692fbffa3b03" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("